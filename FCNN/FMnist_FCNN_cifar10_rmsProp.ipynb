# %%
# !pip install keras keras-hub --upgrade -q
import os
os.environ["KERAS_BACKEND"] = "jax"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.21.1 requires keras-hub==0.21.1, but you have keras-hub 0.23.0 which is incompatible.

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
from keras.datasets import fashion_mnist as cifar10

# Load the dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)

# %%
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
import keras
from keras import layers
from keras.layers import Input

model = keras.Sequential([
    Input(shape=(784,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 567,434 (2.16 MB)
#  Trainable params: 567,434 (2.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:50000]
y_train = y_train[:50000]

# %%
y_train.shape
# Out:
# (50000,)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=40,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.8014 - loss: 0.5389 - val_accuracy: 0.7903 - val_loss: 0.7074
# Epoch 2/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8584 - loss: 0.3848 - val_accuracy: 0.7997 - val_loss: 0.5316
# Epoch 3/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8720 - loss: 0.3461 - val_accuracy: 0.8695 - val_loss: 0.3635
# Epoch 4/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8803 - loss: 0.3235 - val_accuracy: 0.8659 - val_loss: 0.3702
# Epoch 5/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8859 - loss: 0.3116 - val_accuracy: 0.8575 - val_loss: 0.4035
# Epoch 6/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8904 - loss: 0.3026 - val_accuracy: 0.8755 - val_loss: 0.3638
# Epoch 7/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8923 - loss: 0.2933 - val_accuracy: 0.8436 - val_loss: 0.4496
# Epoch 8/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8959 - loss: 0.2855 - val_accuracy: 0.8701 - val_loss: 0.3844
# Epoch 9/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8964 - loss: 0.2800 - val_accuracy: 0.8750 - val_loss: 0.3990
# Epoch 10/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9016 - loss: 0.2759 - val_accuracy: 0.8784 - val_loss: 0.3993
# Epoch 11/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9029 - loss: 0.2724 - val_accuracy: 0.8516 - val_loss: 0.4963
# Epoch 12/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9034 - loss: 0.2747 - val_accuracy: 0.8730 - val_loss: 0.5168
# Epoch 13/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9047 - loss: 0.2678 - val_accuracy: 0.8043 - val_loss: 0.5324
# Epoch 14/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9050 - loss: 0.2706 - val_accuracy: 0.8613 - val_loss: 0.5222
# Epoch 15/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9083 - loss: 0.2644 - val_accuracy: 0.8791 - val_loss: 0.4524
# Epoch 16/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9071 - loss: 0.2590 - val_accuracy: 0.8747 - val_loss: 0.4931
# Epoch 17/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9081 - loss: 0.2562 - val_accuracy: 0.8626 - val_loss: 0.4832
# Epoch 18/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9084 - loss: 0.2558 - val_accuracy: 0.8700 - val_loss: 0.4391
# Epoch 19/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9092 - loss: 0.2592 - val_accuracy: 0.8620 - val_loss: 0.6950
# Epoch 20/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9108 - loss: 0.2589 - val_accuracy: 0.8765 - val_loss: 0.4317
# Epoch 21/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9115 - loss: 0.2523 - val_accuracy: 0.8774 - val_loss: 0.4804
# Epoch 22/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9118 - loss: 0.2533 - val_accuracy: 0.8601 - val_loss: 0.5809
# Epoch 23/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9143 - loss: 0.2507 - val_accuracy: 0.8707 - val_loss: 0.4783
# Epoch 24/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9149 - loss: 0.2497 - val_accuracy: 0.8540 - val_loss: 0.4831
# Epoch 25/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9144 - loss: 0.2472 - val_accuracy: 0.8640 - val_loss: 0.5059
# Epoch 26/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9176 - loss: 0.2403 - val_accuracy: 0.8777 - val_loss: 0.4784
# Epoch 27/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9188 - loss: 0.2381 - val_accuracy: 0.8871 - val_loss: 0.4992
# Epoch 28/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9167 - loss: 0.2410 - val_accuracy: 0.8788 - val_loss: 0.6114
# Epoch 29/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9180 - loss: 0.2396 - val_accuracy: 0.8798 - val_loss: 0.4879
# Epoch 30/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9216 - loss: 0.2389 - val_accuracy: 0.8728 - val_loss: 0.6165
# Epoch 31/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9219 - loss: 0.2354 - val_accuracy: 0.8609 - val_loss: 0.6509
# Epoch 32/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9211 - loss: 0.2363 - val_accuracy: 0.8797 - val_loss: 0.5572
# Epoch 33/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9241 - loss: 0.2338 - val_accuracy: 0.8881 - val_loss: 0.5103
# Epoch 34/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9219 - loss: 0.2320 - val_accuracy: 0.8764 - val_loss: 0.5523
# Epoch 35/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9241 - loss: 0.2247 - val_accuracy: 0.8875 - val_loss: 0.5725
# Epoch 36/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9245 - loss: 0.2291 - val_accuracy: 0.8720 - val_loss: 0.5767
# Epoch 37/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9252 - loss: 0.2260 - val_accuracy: 0.8786 - val_loss: 0.7479
# Epoch 38/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9249 - loss: 0.2251 - val_accuracy: 0.8772 - val_loss: 0.5971
# Epoch 39/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9273 - loss: 0.2285 - val_accuracy: 0.8713 - val_loss: 0.6087
# Epoch 40/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9254 - loss: 0.2289 - val_accuracy: 0.8750 - val_loss: 0.5526

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# We retrain the model to the optimal epochs to avoid overfitting

new_model = keras.Sequential([
    Input(shape=(784,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

new_model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

history = new_model.fit(
    x_train,
    y_train,
    epochs=2,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.7989 - loss: 0.5449 - val_accuracy: 0.7808 - val_loss: 0.5720
# Epoch 2/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8561 - loss: 0.3892 - val_accuracy: 0.8425 - val_loss: 0.4550

# %%
#output model
new_model.save('FMnist_FCNN_cifar10_0_8561_rmsprop.keras')
