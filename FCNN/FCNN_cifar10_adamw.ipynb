# %%
# !pip install keras keras-hub --upgrade -q
import os
os.environ["KERAS_BACKEND"] = "jax"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.21.1 requires keras-hub==0.21.1, but you have keras-hub 0.23.0 which is incompatible.

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
from keras.datasets import cifar10

# Load the dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 32*32*3)
x_test = x_test.reshape(-1, 32*32*3)

# %%
import keras
from keras import layers
from keras.layers import Input

model = keras.Sequential([
    Input(shape=(3072,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,738,890 (6.63 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adamw",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
x_train.shape
# Out:
# (50000, 3072)

# %%
x_val = x_train[-5000:]
y_val = y_train[-5000:]

x_train = x_train[:45000]
y_train = y_train[:45000]

# %%
y_train.shape
# Out:
# (45000, 1)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=40,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.3194 - loss: 1.8796 - val_accuracy: 0.3616 - val_loss: 1.7590
# Epoch 2/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.3932 - loss: 1.6895 - val_accuracy: 0.4268 - val_loss: 1.6272
# Epoch 3/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.4280 - loss: 1.5994 - val_accuracy: 0.4254 - val_loss: 1.6197
# Epoch 4/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.4475 - loss: 1.5436 - val_accuracy: 0.4388 - val_loss: 1.5923
# Epoch 5/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.4657 - loss: 1.4980 - val_accuracy: 0.4678 - val_loss: 1.4995
# Epoch 6/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.4783 - loss: 1.4614 - val_accuracy: 0.4648 - val_loss: 1.5160
# Epoch 7/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 15s 22ms/step - accuracy: 0.4857 - loss: 1.4375 - val_accuracy: 0.4706 - val_loss: 1.4871
# Epoch 8/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.4994 - loss: 1.4020 - val_accuracy: 0.4910 - val_loss: 1.4624
# Epoch 9/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5079 - loss: 1.3819 - val_accuracy: 0.4546 - val_loss: 1.5598
# Epoch 10/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5176 - loss: 1.3469 - val_accuracy: 0.4912 - val_loss: 1.4180
# Epoch 11/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5274 - loss: 1.3279 - val_accuracy: 0.5010 - val_loss: 1.4156
# Epoch 12/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5303 - loss: 1.3088 - val_accuracy: 0.4664 - val_loss: 1.5198
# Epoch 13/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5422 - loss: 1.2832 - val_accuracy: 0.5024 - val_loss: 1.4219
# Epoch 14/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5488 - loss: 1.2582 - val_accuracy: 0.5062 - val_loss: 1.3970
# Epoch 15/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5591 - loss: 1.2357 - val_accuracy: 0.5146 - val_loss: 1.4013
# Epoch 16/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5620 - loss: 1.2188 - val_accuracy: 0.5166 - val_loss: 1.3967
# Epoch 17/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5713 - loss: 1.1983 - val_accuracy: 0.5188 - val_loss: 1.3734
# Epoch 18/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5764 - loss: 1.1786 - val_accuracy: 0.5176 - val_loss: 1.4060
# Epoch 19/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5819 - loss: 1.1638 - val_accuracy: 0.5126 - val_loss: 1.4108
# Epoch 20/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5873 - loss: 1.1476 - val_accuracy: 0.5094 - val_loss: 1.4356
# Epoch 21/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5984 - loss: 1.1209 - val_accuracy: 0.5340 - val_loss: 1.3913
# Epoch 22/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6009 - loss: 1.1098 - val_accuracy: 0.5134 - val_loss: 1.4298
# Epoch 23/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6078 - loss: 1.0862 - val_accuracy: 0.5198 - val_loss: 1.4178
# Epoch 24/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.6165 - loss: 1.0666 - val_accuracy: 0.5220 - val_loss: 1.4455
# Epoch 25/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.6205 - loss: 1.0527 - val_accuracy: 0.5218 - val_loss: 1.4685
# Epoch 26/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6230 - loss: 1.0463 - val_accuracy: 0.5258 - val_loss: 1.4416
# Epoch 27/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6305 - loss: 1.0233 - val_accuracy: 0.5108 - val_loss: 1.4934
# Epoch 28/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6392 - loss: 1.0047 - val_accuracy: 0.5160 - val_loss: 1.5022
# Epoch 29/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6434 - loss: 0.9863 - val_accuracy: 0.5112 - val_loss: 1.5454
# Epoch 30/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6484 - loss: 0.9827 - val_accuracy: 0.5118 - val_loss: 1.5400
# Epoch 31/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6527 - loss: 0.9597 - val_accuracy: 0.5188 - val_loss: 1.5199
# Epoch 32/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6562 - loss: 0.9512 - val_accuracy: 0.5046 - val_loss: 1.6164
# Epoch 33/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6604 - loss: 0.9428 - val_accuracy: 0.5000 - val_loss: 1.6558
# Epoch 34/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6682 - loss: 0.9186 - val_accuracy: 0.5116 - val_loss: 1.5866
# Epoch 35/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6736 - loss: 0.9058 - val_accuracy: 0.5110 - val_loss: 1.5834
# Epoch 36/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6795 - loss: 0.8929 - val_accuracy: 0.5036 - val_loss: 1.6470
# Epoch 37/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6786 - loss: 0.8948 - val_accuracy: 0.5176 - val_loss: 1.6224
# Epoch 38/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6855 - loss: 0.8693 - val_accuracy: 0.5206 - val_loss: 1.6041
# Epoch 39/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.6900 - loss: 0.8552 - val_accuracy: 0.5046 - val_loss: 1.7209
# Epoch 40/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.6969 - loss: 0.8415 - val_accuracy: 0.5046 - val_loss: 1.6987

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# We retrain the model to the optimal epochs to avoid overfitting

new_model = keras.Sequential([
    Input(shape=(3072,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

new_model.compile(
    optimizer="adamw",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

history = new_model.fit(
    x_train,
    y_train,
    epochs=4,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.3145 - loss: 1.8849 - val_accuracy: 0.3780 - val_loss: 1.7505
# Epoch 2/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.3927 - loss: 1.6896 - val_accuracy: 0.3996 - val_loss: 1.6520
# Epoch 3/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.4229 - loss: 1.6092 - val_accuracy: 0.4102 - val_loss: 1.6327
# Epoch 4/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.4471 - loss: 1.5423 - val_accuracy: 0.4484 - val_loss: 1.5481

# %%
#output model
new_model.save('FCNN_cifar10_0_4471_adamw.keras')
