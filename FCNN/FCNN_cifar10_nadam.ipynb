# %%
# !pip install keras keras-hub --upgrade -q
import os
os.environ["KERAS_BACKEND"] = "jax"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.21.1 requires keras-hub==0.21.1, but you have keras-hub 0.23.0 which is incompatible.

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
from keras.datasets import cifar10

# Load the dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 32*32*3)
x_test = x_test.reshape(-1, 32*32*3)

# %%
import keras
from keras import layers
from keras.layers import Input

model = keras.Sequential([
    Input(shape=(3072,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,738,890 (6.63 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="nadam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
x_train.shape
# Out:
# (50000, 3072)

# %%
x_val = x_train[-5000:]
y_val = y_train[-5000:]

x_train = x_train[:45000]
y_train = y_train[:45000]

# %%
y_train.shape
# Out:
# (45000, 1)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=40,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.3387 - loss: 1.8352 - val_accuracy: 0.3820 - val_loss: 1.7152
# Epoch 2/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.4148 - loss: 1.6336 - val_accuracy: 0.4174 - val_loss: 1.6454
# Epoch 3/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.4472 - loss: 1.5481 - val_accuracy: 0.4224 - val_loss: 1.6268
# Epoch 4/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.4659 - loss: 1.4925 - val_accuracy: 0.4262 - val_loss: 1.6074
# Epoch 5/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 17s 25ms/step - accuracy: 0.4828 - loss: 1.4529 - val_accuracy: 0.4684 - val_loss: 1.5064
# Epoch 6/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.4963 - loss: 1.4178 - val_accuracy: 0.4848 - val_loss: 1.4600
# Epoch 7/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5064 - loss: 1.3849 - val_accuracy: 0.4702 - val_loss: 1.5239
# Epoch 8/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5134 - loss: 1.3602 - val_accuracy: 0.4524 - val_loss: 1.5541
# Epoch 9/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5242 - loss: 1.3320 - val_accuracy: 0.4826 - val_loss: 1.4697
# Epoch 10/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5342 - loss: 1.3042 - val_accuracy: 0.4314 - val_loss: 1.7142
# Epoch 11/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.5435 - loss: 1.2774 - val_accuracy: 0.4790 - val_loss: 1.4886
# Epoch 12/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.5528 - loss: 1.2537 - val_accuracy: 0.5024 - val_loss: 1.4252
# Epoch 13/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5590 - loss: 1.2293 - val_accuracy: 0.4944 - val_loss: 1.4440
# Epoch 14/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5666 - loss: 1.2076 - val_accuracy: 0.4992 - val_loss: 1.4337
# Epoch 15/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5750 - loss: 1.1832 - val_accuracy: 0.5106 - val_loss: 1.4102
# Epoch 16/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5832 - loss: 1.1647 - val_accuracy: 0.5156 - val_loss: 1.4259
# Epoch 17/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5926 - loss: 1.1410 - val_accuracy: 0.5214 - val_loss: 1.3823
# Epoch 18/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6001 - loss: 1.1157 - val_accuracy: 0.5026 - val_loss: 1.4645
# Epoch 19/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6053 - loss: 1.1015 - val_accuracy: 0.5190 - val_loss: 1.4389
# Epoch 20/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6126 - loss: 1.0818 - val_accuracy: 0.5082 - val_loss: 1.4554
# Epoch 21/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6166 - loss: 1.0631 - val_accuracy: 0.5122 - val_loss: 1.4448
# Epoch 22/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6252 - loss: 1.0448 - val_accuracy: 0.5144 - val_loss: 1.4593
# Epoch 23/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6309 - loss: 1.0286 - val_accuracy: 0.5054 - val_loss: 1.5432
# Epoch 24/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6350 - loss: 1.0064 - val_accuracy: 0.5212 - val_loss: 1.4718
# Epoch 25/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6433 - loss: 0.9934 - val_accuracy: 0.5206 - val_loss: 1.4842
# Epoch 26/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6491 - loss: 0.9737 - val_accuracy: 0.5130 - val_loss: 1.4910
# Epoch 27/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6556 - loss: 0.9516 - val_accuracy: 0.5064 - val_loss: 1.5651
# Epoch 28/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6605 - loss: 0.9440 - val_accuracy: 0.5144 - val_loss: 1.5266
# Epoch 29/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6652 - loss: 0.9243 - val_accuracy: 0.4914 - val_loss: 1.6450
# Epoch 30/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6668 - loss: 0.9232 - val_accuracy: 0.5134 - val_loss: 1.5928
# Epoch 31/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6780 - loss: 0.8982 - val_accuracy: 0.5076 - val_loss: 1.6115
# Epoch 32/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6794 - loss: 0.8830 - val_accuracy: 0.5186 - val_loss: 1.5982
# Epoch 33/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6896 - loss: 0.8609 - val_accuracy: 0.5136 - val_loss: 1.6443
# Epoch 34/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6917 - loss: 0.8508 - val_accuracy: 0.4944 - val_loss: 1.6910
# Epoch 35/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6969 - loss: 0.8395 - val_accuracy: 0.5136 - val_loss: 1.6454
# Epoch 36/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.7032 - loss: 0.8211 - val_accuracy: 0.4986 - val_loss: 1.7058
# Epoch 37/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.7077 - loss: 0.8086 - val_accuracy: 0.4986 - val_loss: 1.7375
# Epoch 38/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.7124 - loss: 0.7987 - val_accuracy: 0.5162 - val_loss: 1.6987
# Epoch 39/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.7174 - loss: 0.7858 - val_accuracy: 0.5012 - val_loss: 1.7393
# Epoch 40/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.7199 - loss: 0.7768 - val_accuracy: 0.5024 - val_loss: 1.7132

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# We retrain the model to the optimal epochs to avoid overfitting

new_model = keras.Sequential([
    Input(shape=(3072,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

new_model.compile(
    optimizer="nadam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

history = new_model.fit(
    x_train,
    y_train,
    epochs=4,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.3386 - loss: 1.8303 - val_accuracy: 0.3968 - val_loss: 1.7158
# Epoch 2/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.4164 - loss: 1.6300 - val_accuracy: 0.4042 - val_loss: 1.6660
# Epoch 3/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.4497 - loss: 1.5442 - val_accuracy: 0.4152 - val_loss: 1.6376
# Epoch 4/4
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.4678 - loss: 1.4938 - val_accuracy: 0.4650 - val_loss: 1.4996

# %%
#output model
new_model.save('FCNN_cifar10_0_4678_nadam.keras')
