# %%
# !pip install keras keras-hub --upgrade -q
import os
os.environ["KERAS_BACKEND"] = "jax"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.21.1 requires keras-hub==0.21.1, but you have keras-hub 0.23.0 which is incompatible.

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
from keras.datasets import fashion_mnist as cifar10

# Load the dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)

# %%
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
import keras
from keras import layers
from keras.layers import Input

model = keras.Sequential([
    Input(shape=(784,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 567,434 (2.16 MB)
#  Trainable params: 567,434 (2.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="nadam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:50000]
y_train = y_train[:50000]

# %%
y_train.shape
# Out:
# (50000,)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=40,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 15ms/step - accuracy: 0.8316 - loss: 0.4695 - val_accuracy: 0.8601 - val_loss: 0.3972
# Epoch 2/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8728 - loss: 0.3506 - val_accuracy: 0.8707 - val_loss: 0.3532
# Epoch 3/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8834 - loss: 0.3159 - val_accuracy: 0.8623 - val_loss: 0.3833
# Epoch 4/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8902 - loss: 0.2942 - val_accuracy: 0.8798 - val_loss: 0.3330
# Epoch 5/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8980 - loss: 0.2754 - val_accuracy: 0.8859 - val_loss: 0.3231
# Epoch 6/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9023 - loss: 0.2615 - val_accuracy: 0.8872 - val_loss: 0.3132
# Epoch 7/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9078 - loss: 0.2469 - val_accuracy: 0.8874 - val_loss: 0.3136
# Epoch 8/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9129 - loss: 0.2352 - val_accuracy: 0.8803 - val_loss: 0.3339
# Epoch 9/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9150 - loss: 0.2256 - val_accuracy: 0.8815 - val_loss: 0.3603
# Epoch 10/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9168 - loss: 0.2180 - val_accuracy: 0.8899 - val_loss: 0.3284
# Epoch 11/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9207 - loss: 0.2061 - val_accuracy: 0.8873 - val_loss: 0.3345
# Epoch 12/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9260 - loss: 0.1954 - val_accuracy: 0.8913 - val_loss: 0.3136
# Epoch 13/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9267 - loss: 0.1919 - val_accuracy: 0.8916 - val_loss: 0.3362
# Epoch 14/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9299 - loss: 0.1822 - val_accuracy: 0.8944 - val_loss: 0.3236
# Epoch 15/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9320 - loss: 0.1741 - val_accuracy: 0.8870 - val_loss: 0.3555
# Epoch 16/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9343 - loss: 0.1687 - val_accuracy: 0.8899 - val_loss: 0.3578
# Epoch 17/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9372 - loss: 0.1651 - val_accuracy: 0.8891 - val_loss: 0.3542
# Epoch 18/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9403 - loss: 0.1561 - val_accuracy: 0.8923 - val_loss: 0.3545
# Epoch 19/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9408 - loss: 0.1521 - val_accuracy: 0.8979 - val_loss: 0.3331
# Epoch 20/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9437 - loss: 0.1473 - val_accuracy: 0.8917 - val_loss: 0.3903
# Epoch 21/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9464 - loss: 0.1395 - val_accuracy: 0.8903 - val_loss: 0.3680
# Epoch 22/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9472 - loss: 0.1369 - val_accuracy: 0.8881 - val_loss: 0.3994
# Epoch 23/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9482 - loss: 0.1337 - val_accuracy: 0.8969 - val_loss: 0.3795
# Epoch 24/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9506 - loss: 0.1308 - val_accuracy: 0.8933 - val_loss: 0.3892
# Epoch 25/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9525 - loss: 0.1221 - val_accuracy: 0.8967 - val_loss: 0.3917
# Epoch 26/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9545 - loss: 0.1193 - val_accuracy: 0.8920 - val_loss: 0.4187
# Epoch 27/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9553 - loss: 0.1150 - val_accuracy: 0.8924 - val_loss: 0.4088
# Epoch 28/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9579 - loss: 0.1085 - val_accuracy: 0.8952 - val_loss: 0.4277
# Epoch 29/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9582 - loss: 0.1065 - val_accuracy: 0.8878 - val_loss: 0.4397
# Epoch 30/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9586 - loss: 0.1060 - val_accuracy: 0.8959 - val_loss: 0.4453
# Epoch 31/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9608 - loss: 0.1014 - val_accuracy: 0.8901 - val_loss: 0.4971
# Epoch 32/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9617 - loss: 0.0999 - val_accuracy: 0.8911 - val_loss: 0.4381
# Epoch 33/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9626 - loss: 0.0960 - val_accuracy: 0.8932 - val_loss: 0.4529
# Epoch 34/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9637 - loss: 0.0952 - val_accuracy: 0.8928 - val_loss: 0.4556
# Epoch 35/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9648 - loss: 0.0920 - val_accuracy: 0.8984 - val_loss: 0.4978
# Epoch 36/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9645 - loss: 0.0894 - val_accuracy: 0.8928 - val_loss: 0.4716
# Epoch 37/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9650 - loss: 0.0911 - val_accuracy: 0.8950 - val_loss: 0.4492
# Epoch 38/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9662 - loss: 0.0874 - val_accuracy: 0.8964 - val_loss: 0.4616
# Epoch 39/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9690 - loss: 0.0817 - val_accuracy: 0.8928 - val_loss: 0.5040
# Epoch 40/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9704 - loss: 0.0778 - val_accuracy: 0.8920 - val_loss: 0.4945

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# We retrain the model to the optimal epochs to avoid overfitting

new_model = keras.Sequential([
    Input(shape=(784,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

new_model.compile(
    optimizer="nadam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

history = new_model.fit(
    x_train,
    y_train,
    epochs=1,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.8317 - loss: 0.4689 - val_accuracy: 0.8623 - val_loss: 0.3819

# %%
#output model
new_model.save('MNist_FCNN_cifar10_0_8317_nadam.keras')
