# %%
# !pip install keras keras-hub --upgrade -q
import os
os.environ["KERAS_BACKEND"] = "jax"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.21.1 requires keras-hub==0.21.1, but you have keras-hub 0.23.0 which is incompatible.

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
from keras.datasets import cifar10

# Load the dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 32*32*3)
x_test = x_test.reshape(-1, 32*32*3)

# %%
import keras
from keras import layers
from keras.layers import Input

model = keras.Sequential([
    Input(shape=(3072,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,738,890 (6.63 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
x_train.shape
# Out:
# (50000, 3072)

# %%
x_val = x_train[-5000:]
y_val = y_train[-5000:]

x_train = x_train[:45000]
y_train = y_train[:45000]

# %%
y_train.shape
# Out:
# (45000, 1)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=40,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.3149 - loss: 1.8838 - val_accuracy: 0.3734 - val_loss: 1.7591
# Epoch 2/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.3908 - loss: 1.6925 - val_accuracy: 0.4068 - val_loss: 1.6772
# Epoch 3/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.4261 - loss: 1.6039 - val_accuracy: 0.4142 - val_loss: 1.6316
# Epoch 4/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.4450 - loss: 1.5400 - val_accuracy: 0.4448 - val_loss: 1.5565
# Epoch 5/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.4620 - loss: 1.4973 - val_accuracy: 0.4388 - val_loss: 1.5621
# Epoch 6/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.4771 - loss: 1.4653 - val_accuracy: 0.4656 - val_loss: 1.4780
# Epoch 7/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.4875 - loss: 1.4331 - val_accuracy: 0.4740 - val_loss: 1.4622
# Epoch 8/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.4942 - loss: 1.4069 - val_accuracy: 0.4234 - val_loss: 1.6039
# Epoch 9/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.5062 - loss: 1.3815 - val_accuracy: 0.4928 - val_loss: 1.4415
# Epoch 10/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.5151 - loss: 1.3625 - val_accuracy: 0.4802 - val_loss: 1.4599
# Epoch 11/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.5258 - loss: 1.3331 - val_accuracy: 0.4848 - val_loss: 1.4639
# Epoch 12/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5326 - loss: 1.3049 - val_accuracy: 0.4966 - val_loss: 1.4289
# Epoch 13/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5360 - loss: 1.2883 - val_accuracy: 0.4756 - val_loss: 1.4714
# Epoch 14/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5466 - loss: 1.2628 - val_accuracy: 0.4844 - val_loss: 1.4638
# Epoch 15/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5523 - loss: 1.2444 - val_accuracy: 0.5062 - val_loss: 1.4045
# Epoch 16/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.5602 - loss: 1.2237 - val_accuracy: 0.5082 - val_loss: 1.4456
# Epoch 17/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.5646 - loss: 1.2097 - val_accuracy: 0.5134 - val_loss: 1.3809
# Epoch 18/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.5730 - loss: 1.1843 - val_accuracy: 0.4998 - val_loss: 1.4417
# Epoch 19/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.5817 - loss: 1.1642 - val_accuracy: 0.4982 - val_loss: 1.4495
# Epoch 20/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.5879 - loss: 1.1467 - val_accuracy: 0.5100 - val_loss: 1.4208
# Epoch 21/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.5924 - loss: 1.1341 - val_accuracy: 0.5048 - val_loss: 1.4258
# Epoch 22/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6001 - loss: 1.1144 - val_accuracy: 0.4966 - val_loss: 1.4821
# Epoch 23/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6038 - loss: 1.0958 - val_accuracy: 0.5022 - val_loss: 1.4739
# Epoch 24/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6078 - loss: 1.0862 - val_accuracy: 0.4948 - val_loss: 1.4782
# Epoch 25/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6163 - loss: 1.0639 - val_accuracy: 0.5084 - val_loss: 1.4337
# Epoch 26/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6220 - loss: 1.0466 - val_accuracy: 0.5066 - val_loss: 1.4709
# Epoch 27/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6283 - loss: 1.0360 - val_accuracy: 0.4964 - val_loss: 1.5000
# Epoch 28/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6328 - loss: 1.0185 - val_accuracy: 0.5044 - val_loss: 1.4838
# Epoch 29/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6391 - loss: 1.0037 - val_accuracy: 0.4994 - val_loss: 1.5304
# Epoch 30/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6429 - loss: 0.9851 - val_accuracy: 0.5022 - val_loss: 1.5367
# Epoch 31/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6488 - loss: 0.9787 - val_accuracy: 0.4820 - val_loss: 1.6212
# Epoch 32/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6510 - loss: 0.9590 - val_accuracy: 0.5020 - val_loss: 1.5564
# Epoch 33/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6608 - loss: 0.9427 - val_accuracy: 0.4856 - val_loss: 1.6205
# Epoch 34/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6669 - loss: 0.9209 - val_accuracy: 0.4940 - val_loss: 1.6277
# Epoch 35/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6678 - loss: 0.9197 - val_accuracy: 0.4796 - val_loss: 1.6560
# Epoch 36/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.6698 - loss: 0.9136 - val_accuracy: 0.4850 - val_loss: 1.6950
# Epoch 37/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6758 - loss: 0.8936 - val_accuracy: 0.4866 - val_loss: 1.6980
# Epoch 38/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6806 - loss: 0.8823 - val_accuracy: 0.4964 - val_loss: 1.7108
# Epoch 39/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6883 - loss: 0.8642 - val_accuracy: 0.4938 - val_loss: 1.6699
# Epoch 40/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.6898 - loss: 0.8590 - val_accuracy: 0.4926 - val_loss: 1.7843

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# We retrain the model to the optimal epochs to avoid overfitting

new_model = keras.Sequential([
    Input(shape=(3072,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

new_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

history = new_model.fit(
    x_train,
    y_train,
    epochs=3,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/3
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.3224 - loss: 1.8757 - val_accuracy: 0.3672 - val_loss: 1.7516
# Epoch 2/3
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.3970 - loss: 1.6806 - val_accuracy: 0.4184 - val_loss: 1.6455
# Epoch 3/3
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.4256 - loss: 1.5985 - val_accuracy: 0.4174 - val_loss: 1.6281

# %%
#output model
new_model.save('FCNN_cifar10_0_4256_adam.keras')
