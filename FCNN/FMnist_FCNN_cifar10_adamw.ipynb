# %%
# !pip install keras keras-hub --upgrade -q
import os
os.environ["KERAS_BACKEND"] = "jax"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.21.1 requires keras-hub==0.21.1, but you have keras-hub 0.23.0 which is incompatible.

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
from keras.datasets import fashion_mnist as cifar10

# Load the dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("Training data shape:", x_train.shape)
print("Test data shape:", x_test.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)

# %%
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
import keras
from keras import layers
from keras.layers import Input

model = keras.Sequential([
    Input(shape=(784,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 567,434 (2.16 MB)
#  Trainable params: 567,434 (2.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adamw",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:50000]
y_train = y_train[:50000]

# %%
y_train.shape
# Out:
# (50000,)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=40,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8208 - loss: 0.4980 - val_accuracy: 0.8156 - val_loss: 0.4933
# Epoch 2/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8658 - loss: 0.3623 - val_accuracy: 0.8670 - val_loss: 0.3561
# Epoch 3/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8777 - loss: 0.3242 - val_accuracy: 0.8623 - val_loss: 0.3754
# Epoch 4/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8865 - loss: 0.3018 - val_accuracy: 0.8664 - val_loss: 0.3576
# Epoch 5/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8933 - loss: 0.2856 - val_accuracy: 0.8756 - val_loss: 0.3430
# Epoch 6/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8981 - loss: 0.2722 - val_accuracy: 0.8766 - val_loss: 0.3469
# Epoch 7/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9027 - loss: 0.2590 - val_accuracy: 0.8868 - val_loss: 0.3109
# Epoch 8/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9066 - loss: 0.2458 - val_accuracy: 0.8869 - val_loss: 0.3185
# Epoch 9/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9109 - loss: 0.2349 - val_accuracy: 0.8884 - val_loss: 0.3244
# Epoch 10/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9146 - loss: 0.2250 - val_accuracy: 0.8796 - val_loss: 0.3445
# Epoch 11/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9170 - loss: 0.2181 - val_accuracy: 0.8854 - val_loss: 0.3354
# Epoch 12/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9204 - loss: 0.2090 - val_accuracy: 0.8878 - val_loss: 0.3228
# Epoch 13/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9223 - loss: 0.2018 - val_accuracy: 0.8875 - val_loss: 0.3489
# Epoch 14/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9251 - loss: 0.1954 - val_accuracy: 0.8920 - val_loss: 0.3211
# Epoch 15/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9293 - loss: 0.1853 - val_accuracy: 0.8859 - val_loss: 0.3527
# Epoch 16/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9306 - loss: 0.1798 - val_accuracy: 0.8830 - val_loss: 0.3736
# Epoch 17/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9337 - loss: 0.1742 - val_accuracy: 0.8896 - val_loss: 0.3612
# Epoch 18/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9351 - loss: 0.1690 - val_accuracy: 0.8856 - val_loss: 0.3599
# Epoch 19/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9383 - loss: 0.1597 - val_accuracy: 0.8932 - val_loss: 0.3478
# Epoch 20/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9389 - loss: 0.1586 - val_accuracy: 0.8864 - val_loss: 0.3754
# Epoch 21/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9418 - loss: 0.1479 - val_accuracy: 0.8900 - val_loss: 0.3747
# Epoch 22/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9429 - loss: 0.1467 - val_accuracy: 0.8927 - val_loss: 0.3671
# Epoch 23/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9452 - loss: 0.1430 - val_accuracy: 0.8931 - val_loss: 0.3648
# Epoch 24/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9462 - loss: 0.1407 - val_accuracy: 0.8908 - val_loss: 0.3881
# Epoch 25/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9476 - loss: 0.1354 - val_accuracy: 0.8900 - val_loss: 0.3781
# Epoch 26/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9500 - loss: 0.1281 - val_accuracy: 0.8965 - val_loss: 0.3728
# Epoch 27/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9509 - loss: 0.1255 - val_accuracy: 0.8886 - val_loss: 0.3787
# Epoch 28/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9512 - loss: 0.1261 - val_accuracy: 0.8920 - val_loss: 0.4066
# Epoch 29/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9535 - loss: 0.1196 - val_accuracy: 0.8947 - val_loss: 0.3882
# Epoch 30/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9536 - loss: 0.1169 - val_accuracy: 0.8947 - val_loss: 0.4144
# Epoch 31/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9556 - loss: 0.1150 - val_accuracy: 0.8842 - val_loss: 0.4405
# Epoch 32/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9582 - loss: 0.1108 - val_accuracy: 0.8973 - val_loss: 0.3924
# Epoch 33/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9589 - loss: 0.1044 - val_accuracy: 0.8922 - val_loss: 0.4383
# Epoch 34/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9589 - loss: 0.1049 - val_accuracy: 0.8943 - val_loss: 0.4138
# Epoch 35/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9607 - loss: 0.1017 - val_accuracy: 0.8905 - val_loss: 0.4647
# Epoch 36/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9614 - loss: 0.0997 - val_accuracy: 0.8916 - val_loss: 0.4496
# Epoch 37/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9630 - loss: 0.0934 - val_accuracy: 0.8959 - val_loss: 0.4357
# Epoch 38/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9626 - loss: 0.0975 - val_accuracy: 0.8926 - val_loss: 0.4385
# Epoch 39/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9651 - loss: 0.0900 - val_accuracy: 0.8894 - val_loss: 0.4758
# Epoch 40/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9652 - loss: 0.0905 - val_accuracy: 0.8924 - val_loss: 0.4658

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# We retrain the model to the optimal epochs to avoid overfitting

new_model = keras.Sequential([
    Input(shape=(784,)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

new_model.compile(
    optimizer="adamw",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

history = new_model.fit(
    x_train,
    y_train,
    epochs=2,
    batch_size=64,
    validation_data=(x_val, y_val),
    validation_batch_size=128
)
# Out:
# Epoch 1/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.8193 - loss: 0.4967 - val_accuracy: 0.8521 - val_loss: 0.4040
# Epoch 2/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8651 - loss: 0.3662 - val_accuracy: 0.8707 - val_loss: 0.3612

# %%
#output model
new_model.save('FMnist_FCNN_cifar10_0_8651_adamw.keras')
